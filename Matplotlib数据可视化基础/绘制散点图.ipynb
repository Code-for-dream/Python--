# %%
import numpy as np
import matplotlib.pyplot as plt 

# 设置中文显示
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False
             
# 读取数据
data = np.load('data/国民经济核算季度数据.npz',allow_pickle=True)
print(data)
name = data['columns']
print(name)
values = data['values']
print(values)

# 绘图
plt.figure(figsize=(8,7))
plt.scatter(values[:,0],values[:,2],marker='o')
plt.xlabel('年份')
plt.ylabel('生产总值（亿元）')
# plt.ylim((0,22500))
plt.xticks(range(0,70,4),values[range(0,70,4),1],rotation=45)
plt.title('2000-2017年各季度国民生产总值散点图')

#保存展示图片
plt.savefig('tmpsave/2000-2017年各季度国民生产总值散点图.png')
plt.show()
# Out:
# ...
# ['序号' '时间' '国内生产总值_当季值(亿元)' '第一产业增加值_当季值(亿元)' '第二产业增加值_当季值(亿元)'
#  '第三产业增加值_当季值(亿元)' '农林牧渔业增加值_当季值(亿元)' '工业增加值_当季值(亿元)' '建筑业增加值_当季值(亿元)'
#  '批发和零售业增加值_当季值(亿元)' '交通运输、仓储和邮政业增加值_当季值(亿元)' '住宿和餐饮业增加值_当季值(亿元)'
#  '金融业增加值_当季值(亿元)' '房地产业增加值_当季值(亿元)' '其他行业增加值_当季值(亿元)']
# [[1 '2000年第一季度' 21329.9 ... 1235.9 933.7 3586.1]
#  [2 '2000年第二季度' 24043.4 ... 1124.0 904.7 3464.9]
#  [3 '2000年第三季度' 25712.5 ... 1170.4 1070.9 3518.2]
#  ...
#  [67 '2016年第三季度' 190529.5 ... 15472.5 12164.1 37964.1]
#  [68 '2016年第四季度' 211281.3 ... 15548.7 13214.9 39848.4]
#  [69 '2017年第一季度' 180682.7 ... 17213.5 12393.4 42443.1]]

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei' ## 设置中文显示
plt.rcParams['axes.unicode_minus'] = False
data = np.load('data/国民经济核算季度数据.npz',allow_pickle=True)
name = data['columns'] ## 提取其中的columns数组，视为数据的标签
values = data['values']## 提取其中的values数组，数据的存在位置

plt.figure(figsize=(20,7))## 设置画布
plt.scatter(values[:,0],values[:,2], marker='o')## 绘制散点图
plt.xlabel('年份')## 添加横轴标签
#plt.ylim(0,22500)## 设置y轴范围
plt.ylabel('生产总值（亿元）')## 添加y轴名称
plt.xticks(range(0,70,4),values[range(0,70,4),1],rotation=45)
plt.title('2000-2017年季度生产总值散点图')## 添加图表标题
plt.savefig('tmpsave/2000-2017年季度生产总值散点图1.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 设置中文,正常显示字符
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

# 读取数据
data = np.load('data/国民经济核算季度数据.npz',allow_pickle=True)
name = data['columns']
values = data['values']

# 设置画布
plt.figure(figsize=(10,7))

# 绘制散点图
plt.scatter(values[:,0],values[:,3],marker='o',c='red')   # 第一产业
plt.scatter(values[:,0],values[:,4],marker='d',c='blue')  # 第二产业
plt.scatter(values[:,0],values[:,5],marker='v',c='yellow') # 第三产业 

# 设置图像属性
plt.xlabel('年份')
plt.ylabel('生产总值（亿元）')
plt.title("2000-2017年各产业各季度季度生产总值散点图")
plt.xticks(range(0,70,4),values[range(0,70,4),1],rotation=45)
plt.legend(['第一产业','第二产业','第三产业'])
plt.savefig('tmpsave/2000-2017年各产业各季度季度生产总值散点图.png')
plt.show()
